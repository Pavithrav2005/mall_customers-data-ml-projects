# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Drive already mounted at  /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/drive/MyDrive/Mall_Customers.csv')

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.head(10)
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# ...

# %%
df.tail()
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df.shape
# Out:
# (200, 5)

# %%
df.isnull().mean()
# Out:
# CustomerID                0.0
# Genre                     0.0
# Age                       0.0
# Annual Income (k$)        0.0
# Spending Score (1-100)    0.0
# dtype: float64

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]>

# %%
sns.countplot(x='Genre', data=df)
# Out:
# <Axes: xlabel='Genre', ylabel='count'>

# %%
df[df['Age'] == 21].groupby('Spending Score (1-100)')['Annual Income (k$)'].count().sort_values(ascending=False).dropna().head(20).plot(kind='bar')
# Out:
# <Axes: xlabel='Spending Score (1-100)'>

# %%
df.groupby('Genre')['Annual Income (k$)'].count().sort_values(ascending=False).plot(kind='pie')
# Out:
# <Axes: ylabel='Annual Income (k$)'>

# %%
df.groupby('Age')['Annual Income (k$)'].count().sort_values(ascending=False).head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='Annual Income (k$)'>

# %%
df.groupby('Spending Score (1-100)')['Age'].count().sort_values(ascending=True).head(10).plot(kind='pie')
# Out:
# <Axes: ylabel='Age'>

# %%
import sklearn as sklearn

# %%
num_male = df[df['Genre'] == 'Male'].shape[0]
num_female = df[df['Genre'] == 'Female'].shape[0]
plt.pie(
    [num_male, num_female],
    labels=['Male', 'Female'],
      startangle=90,
      autopct='%1.f%%',
    colors=['lavender', 'thistle'])
plt.title('Gender of survey respondants')
plt.show()

# %%
df[df['Annual Income (k$)'] == 78].groupby('Age')['Annual Income (k$)'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='Age'>
